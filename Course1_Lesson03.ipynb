# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python: Module vs Package vs Library vs Framework

# %% [markdown]
# * Module is a file which contains various Python functions and global variables.
#   * It is simply just .py extension file which has python executable code.
#
# * Package is a collection of modules.
#   * It must contains an `__init__.py` file as a flag so that the python interpreter processes it as such.
#   * The `__init__.py` could be an empty file without causing issues.
#
# * Library is a collection of packages.
#
# * Framework is a collection of libraries. This is the architecture of the program.
#
#
# **references:**
#   [1](https://kimconnect.com/python-module-vs-package-vs-library-vs-framework/#:~:text=Library%20is%20a%20collection%20of,Application%20is%20an%20application)
#   [2](https://learnpython.com/blog/python-modules-packages-libraries-frameworks/#:~:text=A%20library%20is%20an%20umbrella,and%20other%20packages%20(subpackages).)
#
# **The words “module”, “package” and “library” are often used interchangeably.**

# %% [markdown]
# ## Python Standard Library

# %%
# math module
import math

# %%
import os 
 
print("Current working directory:", cwd)

# %%
print("Current working directory:", cwd)

# %% [markdown]
# ## Python Libraries (installation required)

# %% [markdown]
# ## Importing a submodule

# %% [markdown]
# ## NumPy

# %% [markdown]
# ### NumPy is a Python library used for working with arrays.

# %% [markdown]
# ### Array Shapes

# %%
import numpy as np

temper = np.array([
    29.3, 42.1, 18.8, 16.1, 38.0, 12.5,
    12.6, 49.9, 38.6, 31.3, 9.2, 22.2
])

# %% [markdown]
# ### Understanding Axes

# %% [markdown]
# ref: [1](https://www.sharpsightlabs.com/blog/numpy-axes-explained/)

# %%
import numpy as np

table = np.array([
    [5, 3, 7, 1],
    [2, 6, 7 ,9],
    [1, 1, 1, 1],
    [4, 3, 2, 0],
])

# %% [markdown]
# ### Slicing arrays

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# ### Broadcasting

# %% [markdown]
# ![](https://numpy.org/doc/stable/_images/broadcasting_2.png)
#
# reference: [1](https://numpy.org/doc/stable/user/basics.broadcasting.html)

# %% [markdown]
# [Example](https://numpy.org/doc/stable/user/basics.broadcasting.html#a-practical-example-vector-quantization)

# %%
from numpy import array, argmin, sqrt, sum
observation = array([111.0, 188.0])
codes = array([[102.0, 203.0],
               [132.0, 193.0],
               [45.0, 155.0],
               [57.0, 173.0]])

# %% [markdown]
# ### Masking and Filtering

# %%
import numpy as np

# %% [markdown]
# ### Transposing, Sorting, and Concatenating

# %%
import numpy as np

a = np.array([
    [1, 2],
    [3, 4],
    [5, 6],
])

# %%
import numpy as np

data = np.array([
    [7, 1, 4],
    [8, 6, 5],
    [1, 2, 3]
])

# %%
import numpy as np

a = np.array([
    [4, 8],
    [6, 1]
])

b = np.array([
    [3, 5],
    [7, 2],
])

# %% [markdown]
# ### Numerical Types: int, bool, float, and complex

# %% [markdown]
# <thead>
# <tr>
# <th>Name</th>
# <th># of Bits</th>
# <th>Python Type</th>
# <th>NumPy Type</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Integer</td>
# <td>64</td>
# <td><code>int</code></td>
# <td><code>np.int_</code></td>
# </tr>
# <tr>
# <td>Booleans</td>
# <td>8</td>
# <td><code>bool</code></td>
# <td><code>np.bool_</code></td>
# </tr>
# <tr>
# <td>Float</td>
# <td>64</td>
# <td><code>float</code></td>
# <td><code>np.float_</code></td>
# </tr>
# <tr>
# <td>Complex</td>
# <td>128</td>
# <td><code>complex</code></td>
# <td><code>np.complex_</code></td>
# </tr>
# </tbody>

# %% [markdown]
# <h4>Data Types in Python</h4>
# <p>By default Python have these data types:</p>
#
# <ul>
# <li><code class="w3-codespan">strings</code> - used to represent text data, the text is given under quote marks. e.g. "ABCD"</li>
# <li><code class="w3-codespan">integer</code> - used to represent integer numbers. e.g. -1, -2, -3</li>
# <li><code class="w3-codespan">float</code> - used to represent real numbers. e.g. 1.2, 42.42</li>
# <li><code class="w3-codespan">boolean</code> - used to represent True or False.</li>
# <li><code class="w3-codespan">complex</code> - used to represent complex
# numbers. e.g. 1.0 + 2.0j, 1.5 + 2.5j</li>
# </ul>

# %% [markdown]
# <h4>Data Types in NumPy</h4>
#
# <ul>
# <li><code class="w3-codespan">i</code> - integer</li>
# <li><code class="w3-codespan">b</code> - boolean</li>
# <li><code class="w3-codespan">u</code> - unsigned integer</li>
# <li><code class="w3-codespan">f</code> - float</li>
# <li><code class="w3-codespan">c</code> - complex float</li>
# <li><code class="w3-codespan">m</code> - timedelta</li>
# <li><code class="w3-codespan">M</code> - datetime</li>
# <li><code class="w3-codespan">O</code> - object</li>
# <li><code class="w3-codespan">S</code> - string</li>
# <li><code class="w3-codespan">U</code> - unicode string</li>
# <li><code class="w3-codespan">V</code> - fixed chunk of memory for other type ( void )</li>
# </ul>

# %% [markdown]
# ### Other examples

# %% [markdown]
# ## SciPy

# %% [markdown]
# SciPy is a scientific computation library that uses NumPy underneath.

# %% [markdown]
# ### Constant Units
# reference: [1](https://www.w3schools.com/python/scipy/scipy_constants.php)

# %% [markdown]
# ### SciPy Optimizers

# %% [markdown]
# Finding Minima

# %%
 # https://en.wikipedia.org/wiki/Broyden%E2%80%93Fletcher%E2%80%93Goldfarb%E2%80%93Shanno_algorithm

# %% [markdown]
# ### SciPy Sparse Data

# %% [markdown]
# CSC - Compressed Sparse Column. For efficient arithmetic, fast column slicing.
#
# CSR - Compressed Sparse Row. For fast row slicing, faster matrix vector products

# %%
import numpy as np
from scipy.sparse import csr_matrix

arr = np.array([0, 0, 0, 0, 0, 1, 1, 0, 2])

# %% [markdown]
# ### SciPy Spatial Data

# %% [markdown]
# #### Triangulation

# %%
import numpy as np


points = np.array([
  [2, 4],
  [3, 4],
  [3, 0],
  [2, 2],
  [4, 1]
])

# %% [markdown]
# #### Convex Hull

# %%
import numpy as np


points = np.array([
  [2, 4],
  [3, 4],
  [3, 0],
  [2, 2],
  [4, 1],
  [1, 2],
  [5, 0],
  [3, 1],
  [1, 2],
  [0, 2]
])

# %% [markdown]
# #### Distance Matrix

# %%
p1 = (1, 0)
p2 = (10, 2)

# %%
p1 = (1, 0)
p2 = (10, 2)

# %% [markdown]
# #### SciPy Interpolation

# %%
import numpy as np

# %% [markdown]
# #### SciPy Statistical Significance Tests

# %%
import numpy as np
from scipy.stats import kstest

# %% [markdown]
# ### let’s calculate $ \int_{-2}^2 \phi(z) dz$
#  , where $\phi$ is the standard normal density

# %% [markdown]
# # end of lesson03
